# %% [markdown]
# ## Combining dataframes and model fitting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import csv files
train = pd.read_csv(
    'train.csv', 
    low_memory=False, 
    nrows=10**6, 
    dtype={
        'row_id': 'int64', 
        'timestamp': 'int64', 
        'user_id': 'int32', 
        'content_id': 'int16', 
        'content_type_id': 'int8',
        'task_container_id': 'int16', 
        'user_answer': 'int8', 
        'answered_correctly': 'int8', 
        'prior_question_elapsed_time': 'float32', 
        'prior_question_had_explanation': 'boolean'
    }
)
question = pd.read_csv('questions.csv')
lecture = pd.read_csv('lectures.csv')
sample_test = pd.read_csv('example_test.csv')

# %%
train = train[train.content_type_id ==0]
train
# Out:
#         row_id  timestamp   user_id  content_id  content_type_id  \
# 0            0          0       115        5692                0
# 1            1      56943       115        5716                0
# 2            2     118363       115         128                0
# 3            3     131167       115        7860                0
# 4            4     137965       115        7922                0
# ...        ...        ...       ...         ...              ...
# 999995  999995   26482248  20949024        8803                0
# 999996  999996   26516686  20949024        4664                0
# 999997  999997   26537967  20949024        4108                0
# 999998  999998   26590240  20949024        5014                0
# 999999  999999   26605316  20949024        9828                0
#
#         task_container_id  user_answer  answered_correctly  \
# 0                       1            3                   1
# 1                       2            2                   1
# 2                       0            0                   1
# 3                       3            0                   1
# 4                       4            1                   1
# ...                   ...          ...                 ...
# 999995                 29            1                   1
# 999996                 30            3                   1
# 999997                 31            1                   0
# 999998                 32            3                   0
# 999999                 33            0                   0
#
#         prior_question_elapsed_time  prior_question_had_explanation
# 0                               NaN                            <NA>
# 1                           37000.0                           False
# 2                           55000.0                           False
# 3                           19000.0                           False
# 4                           11000.0                           False
# ...                             ...                             ...
# 999995                      14000.0                            True
# 999996                      17000.0                            True
# 999997                      18000.0                            True
# 999998                       6000.0                            True
# 999999                      46000.0                            True
#
# [980093 rows x 10 columns]

# %%
# get aggregated data for each user_id
std_accu = train[train.answered_correctly != -1].groupby('user_id')['answered_correctly'].mean().reset_index()
time_total = train[train.answered_correctly != -1].groupby('user_id')['prior_question_elapsed_time'].max().reset_index()
action_total = train.groupby('user_id')['content_id'].count().reset_index()

# %%
std_accu.columns = ('user_id', 'std_accu')
time_total.columns = ('user_id', 'time_total')
action_total.columns = ('user_id', 'action_total')
time_total
# Out:
#        user_id  time_total
# 0          115     55000.0
# 1          124     33333.0
# 2         2746     28000.0
# 3         5382    201000.0
# 4         8623     95000.0
# ...        ...         ...
# 3819  20913319    154000.0
# 3820  20913864     40000.0
# 3821  20938253    243000.0
# 3822  20948951     47000.0
# 3823  20949024     94000.0
#
# [3824 rows x 2 columns]

# %%
std_accu
# Out:
#        user_id  std_accu
# 0          115  0.695652
# 1          124  0.233333
# 2         2746  0.578947
# 3         5382  0.672000
# 4         8623  0.642202
# ...        ...       ...
# 3819  20913319  0.630653
# 3820  20913864  0.333333
# 3821  20938253  0.608779
# 3822  20948951  0.607843
# 3823  20949024  0.312500
#
# [3824 rows x 2 columns]

# %%
question.head()
# Out:
#    question_id  bundle_id  correct_answer  part            tags
# 0            0          0               0     1   51 131 162 38
# 1            1          1               1     1       131 36 81
# 2            2          2               0     1  131 101 162 92
# 3            3          3               0     1  131 149 162 29
# 4            4          4               3     1    131 5 162 38

# %%
# get accuracy rate for each question
train_q = train[train.content_type_id == 0]
# train_q['answered_correctly'].min()
accu_q = train_q.groupby('content_id').answered_correctly.mean().reset_index()
accu_q
# Out:
#        content_id  answered_correctly
# 0               0            0.863014
# 1               1            0.927273
# 2               2            0.560811
# 3               3            0.798995
# 4               4            0.602606
# ...           ...                 ...
# 13071       13518            0.750000
# 13072       13519            0.555556
# 13073       13520            0.700000
# 13074       13521            0.857143
# 13075       13522            0.714286
#
# [13076 rows x 2 columns]

# %%
train_exp = train[['user_id', 'timestamp',
                  'content_id', 'answered_correctly', 
                  'prior_question_elapsed_time', 'prior_question_elapsed_time']]

# %%
# join on user_id

train_exp = train_exp.join(std_accu.set_index('user_id'), on= 'user_id')

# %%
train_exp = train_exp.join(time_total.set_index('user_id'), on= 'user_id')

# %%
train_exp = train_exp.join(action_total.set_index('user_id'), on='user_id')
train_exp
# Out:
#          user_id  timestamp  content_id  answered_correctly  \
# 0            115          0        5692                   1
# 1            115      56943        5716                   1
# 2            115     118363         128                   1
# 3            115     131167        7860                   1
# 4            115     137965        7922                   1
# ...          ...        ...         ...                 ...
# 999995  20949024   26482248        8803                   1
# 999996  20949024   26516686        4664                   1
# 999997  20949024   26537967        4108                   0
# 999998  20949024   26590240        5014                   0
# 999999  20949024   26605316        9828                   0
#
#         prior_question_elapsed_time  prior_question_elapsed_time  std_accu  \
# 0                               NaN                          NaN  0.695652
# 1                           37000.0                      37000.0  0.695652
# 2                           55000.0                      55000.0  0.695652
# 3                           19000.0                      19000.0  0.695652
# 4                           11000.0                      11000.0  0.695652
# ...                             ...                          ...       ...
# 999995                      14000.0                      14000.0  0.312500
# 999996                      17000.0                      17000.0  0.312500
# 999997                      18000.0                      18000.0  0.312500
# 999998                       6000.0                       6000.0  0.312500
# 999999                      46000.0                      46000.0  0.312500
#
#         time_total  action_total
# 0          55000.0            46
# 1          55000.0            46
# 2          55000.0            46
# 3          55000.0            46
# 4          55000.0            46
# ...            ...           ...
# 999995     94000.0            48
# 999996     94000.0            48
# 999997     94000.0            48
# 999998     94000.0            48
# 999999     94000.0            48
#
# [980093 rows x 9 columns]

# %%
train_sample = train_exp.sample(n=50000, random_state=1)
train_sample
# Out:
#          user_id    timestamp  content_id  answered_correctly  \
# 543389  11038066  14199666914        1253                   1
# 55899    1283420   6287796324       10655                   1
# 105089   2223671    491002068        6594                   1
# 679880  13832598   1559002610        6004                   0
# 782731  15956793  18808024091         258                   1
# ...          ...          ...         ...                 ...
# 553486  11412125    426685315        9704                   1
# 350138   6812883   9996944595        4927                   1
# 698978  14442037   6545038401         383                   1
# 486011   9418512  14831215922        7449                   1
# 97946    2041025  12198262381       10733                   1
#
#         prior_question_elapsed_time  prior_question_elapsed_time  std_accu  \
# 543389                      18000.0                      18000.0  0.702160
# 55899                       20000.0                      20000.0  0.828785
# 105089                      31750.0                      31750.0  0.736301
# 679880                      31000.0                      31000.0  0.550000
# 782731                      19000.0                      19000.0  0.672868
# ...                             ...                          ...       ...
# 553486                      39000.0                      39000.0  0.663617
# 350138                      37000.0                      37000.0  0.489549
# 698978                      18000.0                      18000.0  0.551036
# 486011                      40666.0                      40666.0  0.608869
# 97946                       25667.0                      25667.0  0.685010
#
#         time_total  action_total
# 543389    142000.0          2592
# 55899     246000.0          7476
# 105089     79000.0           292
# 679880    125000.0           380
# 782731    300000.0           645
# ...            ...           ...
# 553486    279000.0          3826
# 350138    296000.0          2727
# 698978    199000.0          1352
# 486011    300000.0          7261
# 97946     300000.0          4343
#
# [50000 rows x 9 columns]

# %%
# export sampled data
train_sample.to_csv('train_sample.csv', index = False)
